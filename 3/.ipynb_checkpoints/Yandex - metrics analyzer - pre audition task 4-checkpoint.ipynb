# %%
import numpy as np
import scipy as sp
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib

df = []

df.append(pandas.read_csv("Images_Russia.csv", sep=";",index_col="Datetime"))
df.append(pandas.read_csv("Weather_Russia.csv", sep=";",index_col="Datetime"))

df[0].shape, df[0][:2]
# Out:
# ...
# ((186, 2),             Monthly  Average daily
#  Datetime
#  2008-05-01  6608910         717430
#  2008-06-01  6362910         679620)

# %%
date_ranges = [] 

for i in dfs:
    pd.date_range(df[i].index.tolist()[0], df[].index.tolist()[-1], freq='MS')

len(date_range) == df.shape[0]
# Out:
# False

# %%
df.drop_duplicates(inplace=True)
len(date_range) == df.shape[0]
# Out:
# True

# %%
f = plt.figure(figsize=(10, 10), dpi=80)
grid = matplotlib.gridspec.GridSpec(1,1)


plt.suptitle(u'Посещаемость', verticalalignment='top', horizontalalignment='left', x=0.1,  fontsize=36)
plt.plot(df)
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-02b4b109d313> in <module>()
#       4
#       5 plt.suptitle(u'Посещаемость', verticalalignment='top', horizontalalignment='left', x=0.1,  fontsize=36)
# ----> 6 plt.plot(df)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
# ...

# %%
f = plt.figure(figsize=(23, 10), dpi=80)
grid = matplotlib.gridspec.GridSpec(1,1)


plt.suptitle(u'Посещаемость Погоды', verticalalignment='top', horizontalalignment='left', x=0.1,  fontsize=36)
plt.plot(df2)
